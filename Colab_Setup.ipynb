# %% [markdown]
# # Google Colab Setup

# %% [markdown]
# We first need to clone the repository that contains the datasets that will be used as part of this course.
# Since this course uses distinct workbooks for each module, the first thing we'll do in each is to clone the dataset reposotiry.  This will ensure we have it locally in the event we have started a new Colab session.

# %%
# !git clone https://github.com/awsdevguru/PearsonMLFoundations.git

# %% [markdown]
# Once the repository is cloned within your instance, you should see a directory called PearsonMLFoundations if the click the folder icon on the left.
#
# ![folder icon](data:image/png;base64,...)

# %% [markdown]
# Run a quick test on the Titanic dataset.

# %%
import pandas as pd

try:
    # Adjust the path if your titanic dataset is located elsewhere
    titanic_df = pd.read_csv('/content/PearsonMLFoundations/data/titanic/titanic-dataset.csv')

  # Count total number of people
    total_people = titanic_df.shape[0]

    # Count people aged 25
    people_aged_25 = titanic_df[titanic_df['Age'] == 25].shape[0]

    print(f"Total number of people: {total_people}")
    print(f"Number of people aged 25: {people_aged_25}")
except FileNotFoundError:
    print("Error: Titanic dataset not found at the specified path. Please verify the path.")
except KeyError:
    print("Error: 'Age' column not found in the dataset. Please check column names.")
