# %% [markdown]
# # Google Colab Setup

# %%
# !git clone https://github.com/awsdevguru/PearsonMLFoundations.git
# Out:
# Cloning into 'PearsonMLFoundations'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 20 (delta 6), reused 13 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (20/20), 26.90 KiB | 6.73 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
